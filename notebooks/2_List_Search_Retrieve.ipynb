# %% [markdown]
# # Copyright 2022 Cognite AS
#
# ## Import the Libraries and Modules

# %%
import sys
from pathlib import Path

utils = str(Path("../utils").resolve())
if utils not in sys.path:
    sys.path.append(utils)

from cognite_auth import interactive_client

# %% [markdown]
# ## Create the Cognite Client

# %%
c = interactive_client()

# %% [markdown]
# ## List operation
#
# **Code Pattern**
# `client.<cdf_resource_type>.list()`
# where **cdf_resource_type** = { data_sets, assets, time_series, events, files, labels, sequences, relationships ... }

# %% [markdown]
# ### List the CDF Resource types

# %%
c.data_sets.list()
# Out:
# DataSetList([<cognite.client.data_classes.data_sets.DataSet at 0x1e1f1555490>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1787710>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1787910>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1e20d1490>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1785350>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1764410>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1773cd0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f105ef90>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1e2268e10>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f178d450>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1764d10>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1783690>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f179b390>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1764b10>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a3850>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a3810>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a3690>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a37d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a3790>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a3750>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a3710>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a36d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a38d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a3910>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f17a3990>])

# %%
c.assets.list(limit=5)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x1e1f1773b50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f17811d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f1b45dd0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1e225b250>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1e20e0c10>])

# %%
df = c.time_series.list(limit=None).to_pandas()

# %%
df.shape
# Out:
# (2089, 12)

# %%
c.events.list(limit=5)
# Out:
# EventList([<cognite.client.data_classes.events.Event at 0x1e1e2269b10>,
#            <cognite.client.data_classes.events.Event at 0x1e1f2fee110>,
#            <cognite.client.data_classes.events.Event at 0x1e1f32e9d50>,
#            <cognite.client.data_classes.events.Event at 0x1e1f1ad7890>,
#            <cognite.client.data_classes.events.Event at 0x1e1f1754610>])

# %%
c.files.list(limit=5)
# Out:
# FileMetadataList([<cognite.client.data_classes.files.FileMetadata at 0x1e1f36f4710>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f36f5050>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f36f4bd0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f36f47d0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f36f4790>])

# %% [markdown]
# Similar code for listing other resource types
#
#
# ```
# c.labels.list()
# ```
# ```
# c.sequences.list()
# ```
# ```
# c.relationships.list()
# ```

# %%
c.labels.list(limit=5)
# Out:
# LabelDefinitionList([<cognite.client.data_classes.labels.LabelDefinition at 0x1e1e2268990>,
#                      <cognite.client.data_classes.labels.LabelDefinition at 0x1e1f30de2d0>,
#                      <cognite.client.data_classes.labels.LabelDefinition at 0x1e1f1b2df50>,
#                      <cognite.client.data_classes.labels.LabelDefinition at 0x1e1f3274150>,
#                      <cognite.client.data_classes.labels.LabelDefinition at 0x1e1f381a2d0>])

# %%
c.sequences.list(limit=5)
# Out:
# SequenceList([<cognite.client.data_classes.sequences.Sequence at 0x1e1f381b950>,
#               <cognite.client.data_classes.sequences.Sequence at 0x1e1f34bc090>,
#               <cognite.client.data_classes.sequences.Sequence at 0x1e1f38454d0>,
#               <cognite.client.data_classes.sequences.Sequence at 0x1e1f38450d0>,
#               <cognite.client.data_classes.sequences.Sequence at 0x1e1f3844750>])

# %%
c.relationships.list(limit=5)
# Out:
# RelationshipList([<cognite.client.data_classes.relationships.Relationship at 0x1e1f32e9cd0>,
#                   <cognite.client.data_classes.relationships.Relationship at 0x1e1f3845cd0>,
#                   <cognite.client.data_classes.relationships.Relationship at 0x1e1f3846190>,
#                   <cognite.client.data_classes.relationships.Relationship at 0x1e1f3844150>,
#                   <cognite.client.data_classes.relationships.Relationship at 0x1e1f3844910>])

# %% [markdown]
# ### Filter the list results

# %% [markdown]
# using label filter, the data in cdf doesn't have these labels. But it is an example on how to filter with labels

# %%
from cognite.client.data_classes import LabelFilter

# %%
c.assets.list(labels=LabelFilter(contains_all=["industrial-assets"]),limit=5)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x1e1f1755c10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1e20e8190>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3833bd0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3847e50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38456d0>])

# %%
c.assets.list(labels=LabelFilter(contains_any=["industrial-assets"]))
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x1e1f3846b10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3845050>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3847010>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3824750>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3826d10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3824a90>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fc650>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fc8d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fc950>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3825d50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fccd0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fd150>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fc150>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38ff050>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fef50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38febd0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fe9d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fe8d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fe6d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fe650>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fe550>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fe3d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fe2d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fe1d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38fdfd0>])

# %% [markdown]
# Other filters

# %%
c.data_sets.list()
# Out:
# DataSetList([<cognite.client.data_classes.data_sets.DataSet at 0x1e1f36f4fd0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1b8b190>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f1b2e050>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f35ca450>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f35c8dd0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38fc110>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38fd250>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38fc610>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38fc0d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38ff450>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38fc310>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38fd5d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38fc810>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38fd8d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3825390>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3824fd0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3825350>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3825010>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3825050>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3825110>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3825210>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3825090>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3824550>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3825190>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3827110>])

# %%
c.data_sets.list(write_protected=True)
# Out:
# DataSetList([<cognite.client.data_classes.data_sets.DataSet at 0x1e1f38188d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f381add0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38189d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3819bd0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38335d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3832ed0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3830f10>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3831690>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3831450>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f38337d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3833690>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3833d50>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f3831d90>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a910>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a8d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a750>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a890>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a850>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a810>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a7d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a790>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a710>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a9d0>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390a990>,
#              <cognite.client.data_classes.data_sets.DataSet at 0x1e1f390aa10>])

# %%
c.assets.list(root=True)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x1e1f36f4250>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f1765690>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d22d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d0250>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d04d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d1a90>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d0190>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d0b10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3390>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d0390>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d0290>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d2310>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3290>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3110>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3250>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d32d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3190>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3150>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d30d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3350>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d31d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3410>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3450>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d3490>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1
# 8849041413371463
# 8853993067379870
# 8854787564827350
# 8855088214848481
# 8857673620794955
# 8858341796483974
# 8863103723706832
# 8875736125476488
# 8884586067829580
# 8885906891088429
# 8892837693829416
# 8897004932475098
# 8900536827183903
# 8905717659831811
# 8910920545776774
# 8912108052353593
# 8915127684162281
# 8931415933035631
# 8931807512379695
# 8936848950370922
# 8937288644036510
# 8941192889025716
# 8951987396216694
# 8956090836557690
# 8972180296200736
# 8972707006396622
# 8982667033174558
# 8996210909288140
# 9005720873673750

# %% [markdown]
# When List is too big, then use the **chunk_size** parameter to get the list in chunks

# %%
for data_set_list in c.data_sets(chunk_size=5):
    print([x.name for x in data_set_list]) # do something with the list
# Out:
# ['TestDataset_pawara', 'pawel_world_info', 'my_example_dataset', 'aleksander_my_example_dataset', 'Crístian2_world_info']
# ['world_info_jack', 'world_info_jack_11', 'world_info_jack', 'world_info_Timi', '1st level']
# ['my example', 'world_info_mohsen', 'world_info_bhaskar', 'kiyoshi_world_info', 'world_info_jack_SAYAN']
# ['patrick1998_world_info', 'test', 'Prince_example_dataset', '1st level K', 'SofieHaug_example_dataset']
# ['jonathan_world_info', 'Srujana_world_info', 'my_example_dataset_wu', 'ole_wammer_world_info2', 'smrsgv_info_jack']
# ['my_example_dataset_rodrigo', 'Test', 'my_example_dataset_temp', 'third example', 'hanan_world_info']
# ['Could anyone help remove this?', 'GPaulo2000-IFSDB', '1stLevel', 'a_my_name_example_dataset', 'gcbiotec_world_info']
# ['patrick1998_world_info', 'world_info_test_2', 'TestDataset', 'world_info_jack_sohaib', 'mp_two_dataset']
# ['Test set', 'raj_world_info', 'ruben1984_example_dataset', 'write-protected-data', 'my_dataset']
# ['krishna2001-Aveva.Net', 'vetle_world_test', 'world_info_shiva', 'world_info_beni', 'Alex_world_info']
# ['my example', 'Shiva', 'TestNK', 'world_info_jack', 'Andreea_world_info']
# ['world_info_jack_novajj', 'world_info_andrew', 'Rafli_world_info', 'irma_test', 'world_info_wei2010']
# ['1st level-gs', 'my_example_dataset', 'heydar_worl_info', 'my_example_dataset_www', 'Gayathri_world_info']
# ['dil_world_info', 'Maciukas_example_dataset', 'Andreea_world_info', 'Shiva', 'test_dataset8']
# ['my_example_dataset_vgr', 'world_info_areisdorf2', 'Maciej_world_info', 'second example', 'world_info_jack_as']
# ['world_info_sofie', 'gann2023-AvevaNet', 'Dzmitry1994_world_info', 'Vijaya_dataset', 'Tiago_world_info']
# ['camilla1996_world_info', 'Arpita2020-AvevaNet', 'PM_world_info', 'my_example_dataset23', 'world_info_krutip']
# ['mylittlepony_world_info', 'mylittlepony_world_info', 'Jorgen_world_info', 'third example', 'world_info_chandc']
# ['my_example_dataset_006', 'hola', 'lsun_world_info', 'myworld_info_jack', 'DipeshYogi1994_world_info']
# ['faraz_alm', 'Rui77', 'Nick0000-IFSDB', 'second example', 'world_info_jackcity']
# ['my_example_dataset', 'my_example_dataset_1', 'world_info_andrew', 'amitoj_world_info', 'rsk_ds1']
# ['world_info_jack', 'world_info_jack_njj', 'bojja_world_info', 'faisal_dataset', 'FirstnameBirthyear-AvevaNet']
# ['mfc', 'my_example_dataset_Him', 'Dag1985_2_example_dataset', 'world_info_andrew', 'world_info_jack_Manv']
# ['rawan_world_info', 'Adriano2024_data_set', 'world_info_jack_99999999', 'world_data123', 'Rafli_world_info']
# ['christian_world_info', 'world_info_john', 'SIOD1980-AvevaNet', 'neil_example_dataset', 'Mudassir_world_info']
# ['gcbiotec_world_info1902A', 'mylittlepony_world_info', 'my_example_dataset_001', 'mohammed_al_safwan_example_dataset', 'world_info_adeeb']
# ['my_example_dataset_test1', 'world_info_mugless', 'Mat1989_dataset', 'TatVF_world_info', 'my_example_dataset']
# ['third example', 'test_world_info', 'faisal_dataset', 'Rajat1985-IFSDB', 'JorgenAa_world_info']
# ['my_example_dataset', 'lucas2000-ds', 'FirstnameBirthyear-AvevaNet', 'world_info_jack_mm', 'dalvania_world_info']
# ['chand_world_info', 'wu_world_info', 'world_data', 'Mudassir_world_info', 'neil_v_world_info2']
# ['world_info_timo', 'teodor_world_info', '2nd level', 'Ruslan_world_info', 'world_info_Kush']
# ['emmab_world_info', 'world_info_academy2', 'pawel-test-dataset', 'second example', 'hmnasri-CDF3']
# ['world_info_andrew', 'smart-home-dataset', 'world_info_jack', 'angelica_world_info', 'camilla1996_world_info']
# ['Crístian_world_info', 'kimsb_world_info', 'JorgenAa_world_info', 'Mohamed_example_dataset', 'caroline_f_world_info']
# ['my_example_datasetcas', 'vinicius_peres_world_info', 'world_info_kailash', 'second example', 'Mikalay1991:my_example_dataset']
# ['heman_dataset', 'world_info_wwu_H2', 'frendi_world_info', 'Diana_world_info', 'world_info_1991_2']
# ['clement_world_info', 'john_world_info', 'sharizan1981_dataset2', 'my_example_dataset_Long', 'my_example_dataset']
# ['world_info_kruti', 'gayathri_world_info', 'Saurabh_world_info', 'wael__world_info', 'christian_world_info']
# ['LNDR_world_info', 'world_info_jack', 'world_info_jack', 'Itika_Dataset', 'teodor_world_info']
# ['my_example_dataset-test', 'Arya_example_dataset', 'Alq1997-AvevaNet', 'Hariharan_world_info', 'Dipesh1994_world_info']
# ['world_info_jack', 'world_info_juju', 'Srujana_world_info', 'EmiliesDS_v3', 'world_info_nick']
# ['Ravi_World_info3', 'Mohamed1996', 'Jorgen_world_info', 'world_info_wwu', 'SampleDataset23']
# ['Maksym1981-1-dataset', 'my_example_dataset11', 'Ajit1992-IFSDB', 'amel_world_info_jack', 'Emilie_world_info']
# ['test_equip', 'elize_world_info', 'Timi_dataset1', 'my_example_dataset', 'world_info_jack']
# ['John7638', 'TestDataset_pawra', 'grobb_ho_dataset', 'first level', 'kiyoshi_world_info']
# ['JH 1st level', 'aarifov_world_info', 'world_info_mi', 'subodh_world_info', 'Shaurya_DataSet']
# ['Ahmad1997-ds', 'andrew_world_info', 'afrendi_world_info', 'DP_TestDataSet2', 'NKTest123']
# ['akhilppujyamdataset', 'mylittlepony_world_info', '111st level', 'wu_world_info', 'third example']
# ['Muddassirmm1', 'world_info_jack', 'christian_world_info', 'ruben_world_info', 'world_info_jack']
# ['lala_level', 'my_example_dataset_abu', 'jd1980-AvevaNet', 'my_example_dataset', 'world_info_Sofie']
# ['disha_world_info_jack', 'Amin1987-ds', 'world_info_jack', 'clement_world_info', 'my_example_datasetmm']
# ['yahya_world_info', 'third example', 'Mudassir_world_info', 'test1', 'world_info_jack_1337']
# ['Srujana_world_info', 'world_info_jack_1964', 'JohnS1984_world_info', '2nd level', 'daniel_world_info']
# ['csv', 'yeshwanth_example_data', 'world_info_jack', 'world_info_jack_t', 'world_info_jack_ass']
# ['Arpita2021-IFSDB', 'pavko_example_dataset', 'christian_world_info', '3st level', 'world_info_mi2']
# ['mikita_world_info_jack', 'NKTest', 'vgr_world_info', 'Mallesh1993-AvevaNet', 'world_info_test_222']
# ['Jorgen1990_example_dataset', 'world_info', 'world_info_jack', 'emma_world_info', 'pavan1978-AvevaNet']
# ['Mudassir_world_info', 'name', 'Ravi_World_info3', '11st level', 'testds']
# ['my_example_dataset', 'my_example_dataset2', 'Shaurya_999', 'Saurabh_world_info', 'my_example_dataset2']
# ['grrr109 test data set name', 'shawn_ts', 'world_info_abhinav', 'world_info_jack', 'PM_world_info']
# ['Arya_World_Info', 'GCH_world_info', 'my_example_11_dataset', 'world_info_jack', 'world_info_jack']
# ['Abiinfojack', 'ahmad_world_info', 'wael__world_info2', 'tfrendi_world_info', 'my example']
# ['FirstnameBirthyear-IFSDB', 'third example', 'world_info_amitoj', 'kailash193-Avevanet', 'world_info_jack_121']
# ['srujana_world_info', 'world_info_maksym1981_1', 'irma_test', 'world_info_douglas', 'world_info_jack']
# ['john_example_dataset', 'world_info_abhinav', 'srujana_world_info', 'my_example_dataset', 'Yining1974-IFSDB']
# ['world_info_jack', 'EH_world_info3', 'world_info_jack', 'ruben_world_info', 'Jason1990_world_info']
# ['mylittlepony_example_dataset', 'world_info_halit', 'Hasan_Hindi_example_dataset', 'Srmk_world_info', 'world_info_jack3']
# ['mylittlepony_world_info', 'my_example_dataset', 'my_example_dataset_x', 'heydar_worl_info', 'dpg_world_info']
# ['world_info_jack', '1st level', 'ariel_world_info', 'my_abhi_dataset', 'Aman1997-AvevaNet']
# ['rdb_example_dataset', 'my_test_dataset', 'my_example_dataset', 'world_info', 'ruben_world_info']
# ['HydP2023', 'world_info_giovanna', '2nd level', 'my_example_dataset_par', 'camilla_example_dataset']
# ['Yahya1991-AvevaNet', 'world_info_marissa', 'E_example_dataset', 'christian_world_info', 'cc_my_example_dataset']
# ['world_info_academy', 'my_example_datasetca', '1st level_m', 'world_info_jack', 'breno_word_info']
# ['rdb_world_info', 'EH Dataset', 'sebastian1999_world_info', 'Muhammed_Muddaththir_world_info', 'dawei_world_info_jack']
# ['world_info_tb11', 'name', 'world_info_jack', 'world_info_jack_hv', 'Maciej_world_info']
# ['jayme_world_info', 'world_info_jack', 'christian_world_info', 'world_info_mfc', 'Shiva']
# ['irma_test', 'srmk', 'my_veryown_dataset', 'ariel_world_info', 'world_info_jack2']
# ['montadahar:my_example_dataset', 'mylittlepony_world_info', 'delete_me', 'ds1', 'meher']
# ['johnzhu-ds', 'first level', 'my_test_ds', 'world_info_jack_daniel', 'world_info_sid']
# ['jujus_dataset', 'mfc_world_info', 'christian_world_info', '1st level_m', 'gabor_world_info']
# ['henderson_world_infov2', 'world_info_jack2', 'Ricardo_example_dataset', 'world_info_jj', 'anj_example_dataset']
# ['tom_world_info', 'nick_world_info', 'my example', 'my_example_dataset', 'rena1990_world_info_jack']
# ['legit_dataset', 'mauricio2_example_dataset', 'world_info_jack', 'PM_world_info', 'kliang-test-ds']
# ['Krystal1986-AvevaNet', 'muygurworld_info', 'world_info', 'ds_2', 'Mark303-AvevaNet']
# ['3rd_level', 'Jaiprakash1988-AvevaNet.', 'second example', 'PM_world_info', 'SumitB1998-IFSDB']
# ['LNDR_world_info_2', 'jonH_world_info', 'mojtaba_world_info', 'talal_world_info', 'name']
# ['jeeva_world_info', 'Mikalay1991:world_info', 'my_example_dataset_PM', 'ali_htx', 'JFH_world_info']
# ['FirstnameBirthyear-AvevaNet', 'world_info_GCH', 'JP my_example_dataset', 'Magnus1994-DS', 'Abdulmonim_World_info']
# ['prueba_example_dataset', 'VFMProject_ClientCompany_Roger', 'Own_Create_dataset', 'phils_world_info', 'DZ_world_info']
# ['magnus_world_data', 'AM-Test', 'md_faraz', 'subham_world_info', 'irma_test']
# ['world_info_jack_MS', 'world_info_jack_name', 'world_info_jack', 'Adriano2024_101_world_info_level1', 'Raluca_world_info']
# ['world_info_jack', 'world_info_afi', 'world_info_jack', 'world_info_tim', 'world_info_diego']
# ['world_info_GCH', 'Simon_world_info', 'vetle_example_dataset', 'PM_world_info', 'world_info_afrendi']
# ['test_dataset2', 'Compressor1992-AvevaNet', 'viniaperes_world_info', 'world_info_mark304', 'world_info_1991_3']
# ['irma_test', 'world_info_andreea1', 'world_info_ole2', 'Jorgen_world_info', 'Him2_dataset']
# ['Hasan Hindi World Info', 'world_info_jack_new', 'my_example_dataset', '14_world_info_jack', 'jz_world_info']
# ['world_info_jack2222', 'jeeva_world_info', 'MRosado_world_info', 'FirstnameBirthyear-AvevaNet', 'my_example_dataset']
# ['anik_example_dataset', 'dzmitry1991_world_info', 'test', 'gcbiotec_world_info2002B', 'kiyoshi_world_info']
# ['Mudassir_world_info', 'andreas_world_info', '2nd level', 'Abu_world_info', 'second example']
# ['aman1997-IFSDB', 'ariel_world_info', 'my_example_dataset', 'mauricio-world-info-test-exercise2', 'E_world_info']
# ['Sumedh_Dataset', 'Ruslan_world_info', 'my_example_datasetq', 'Mikita1994-dataset', 'test_dataset1']
# ['NKTest123', 'Christian_world_info', 'grigorii_world_info', 'Function pipeline configuration', 'my_example_data_set']
# ['world_info_jack-1', 'Mohamed1996', 'JP_world_info', 'world_info_jack', 'Jonas_example_dataset']
# ['yesh4507', 'Saketh1991_data_set', 'NKTest1234', 'xiao_example_dataset', 'world_info_jack_5']
# ['EH_world_info2', 'Pablo1971-AvevaNet', 'ahmed_dataset', 'world_info_jack', 'world_info_kkk']
# ['world_info_jack', 'FirstnameBirthyear-AvevaNet', 'Aranya_world_info', 'world_info_academy', 'first level']
# ['meghna_world_info', 'third example', 'world_info_douglas', 'world_info_xyz', 'world_info']
# ['Yashwanth_data', 'GCH_world_info', 'world_info_jack', 'TestDataset', 'Ravi_World_info']
# ['EmiliesDS_v2', 'aarne_world_info', 'Simon_example_dataset', 'Tat_world_info', 'my_example_dataset']
# ['michael_world_info', 'world_info_mfc3', 'world_info_jack2_new', 'world_info_jack', 'first level']
# ['krny_world_info_jack2', 'world_info_jack', 'my_example_dataset', 'world_info_jack', 'NehaSingh_example_dataset']
# ['marissa_data_set', 'AndreasNordby_world_info', '1st lvl', 'christian_world_info', 'Aditya1999-AvevaNet']
# ['Fred1_example_dataset', 'HA2023', 'World info', '1st level', 'Yahya1991-IFSDB']
# ['DipeshYogi_example_dataset', 'Aidar_world_info', 'world_info_jack7059', 'irma_test', 'world_info_mm2']
# ['Diana_test', 'Gaurav Rajurkar_world_info', 'christian_world_info', 'LNDR-Data-Set', 'world_info_camilla']
# ['my_example_datasettestzp', 'yougiyou2000-AvevaNet', 'agnes_world_info', 'Aidar_world_info', 'Aranya5_world_info']
# ['lucas-2000-world_info', 'world_info_Thilak', 'mads_world_info', 'magnus_world_info', 'world_info_jack']
# ['T_dataset', 'third example', 'world_info_amel', 'world_info_jack', 'third example']
# ['world_info_jack_555', 'Simon_world_info', 'world_info_jack_sid01', 'world_info_jackG', 'cp_wells']
# ['world_info_maksym1981_3', 'world_info_Root_Assert_Error_Test_011', 'kliang_world_info', 'Patrick1998-AvevaNet', 'test_sensor_1']
# ['dataSet1demo', 'Aranya2_world_info', 'grigorii_world_info2', 'YuiNish', 'world_info_jack']
# ['jz_world_info', 'amelfrendi_world_info', 'world_info_jack_005', 'delete_me', '1st level']
# ['Andreea09', 'Crístian1_world_info', 'my_example_dataset', 'yen_example_dataset', None]
# ['world_info_jack2', 'mduque_world_info', 'toye_world_info', 'world_info_jack', 'ds_3']
# ['greynoso71_world_info', 'dpg2_world_info', '2nd level', 'world_info', 'EH_world_info4']
# ['johannes_world_info', 'Rafli_world_info', 'daniel_world_info', 'world_info_Vipul', '3th level-gs']
# ['xiaoniuzhang_world_info', 'patrick1998_world_info', 'pavko_world_info', 'world_info_doug', 'world_info_Root_Assert_Error_Test']
# ['world_info_jack_1990_aida', 'Sai1988-AvevaNet', '2nd level', 'Cognite', 'Elize_example_dataset']
# ['tsk_my_example_dataset', 'faisal_world_info', 'pligarcia_example_dataset', 'vetle_world_info', 'Kushagra_1_world_info']
# ['Mudassir_world_info', 'Dag1985_example_dataset', 'GCH_world_info', 'Rostyslav1984-IFSDB', 'JP 1st level']
# ['003Khobar_world', 'Alex1995_world_info', 'world_info_jack_23', 'Hariharan_world_info', 'dasor_world_info']
# ['gabor_world_info', 'world_info_sky', 'world_info_moe7', 'jd1980-IFSDB', 'henderson_world_info']
# ['second example', 'second example', 'Mikalay1991:world_info', 'Maciej_world_info', 'heydar_worl_info']
# ['4th level', 'my_example_dataset_dw', 'Dzmitry_world_info', 'evg-1980_dataset', 'my_example_dataset']
# ['rsk_dataset', 'world_info_shehan', 'world_info_muglessdurry', 'world_info_jack23', 'world_info_jack']
# ['Jorgen_world_info', 'world_info_daniel1991', 'Hachem_example1', 'world_info_jack_sohaib1', 'my_example_dataset_PJM']
# ['world_info_jack', 'Balcos_world_info', 'irma_test', 'Miles_example_dataset', 'world_info_maksym1981']
# ['RI_world_info', 'my_example_dataset', 'Task_126_ds_python', 'Ruslan_world_info', 'wu2010_world_info']
# ['world_info_moe6', 'lucas-2000-ds', 'Mohammed1995', 'krishna2001-IFSDB', 'my-custom-dataset']
# ['my_example_dataset', 'cristian', 'EH_world_info5', 'LC_1st level', 'Gaurav Rajurkar_world_info']
# ['srmk', 'Sample_Veda', '1st level', 'my_cool_example_dataset', 'Ravi_dataset2']
# ['world_info_jack', 'world_info_jack_Manvendra', 'Vani_99-ds', 'irma_test', 'yeshwanth_45']
# ['Vani_1999', 'irma_test', 'Harsha2000-IFSDB', 'sofie_dataset', 'ola_world_info']
# ['my_example_dataset', 'nick_world_info', 'world_info_chirag', 'my_example_dataset_nikhil', 'chand_world_info2']
# ['world22_info_jack', 'andreea', 'lsun_example_dataset', 'world_info_vero', 'faraz_alam']
# ['my example', '2nd level', 'Aldo_world_info', 'dpg_example_dataset', None]
# ['second example', 'ariel_world_info', 'VFMP_Sf05ynhm0v', 'world_info_jayanth', 'Maria_world_info']
# ['DP_TestDataSet', '2nd level_m', 'vetle_world_info', 'Jorgen_world_info', '5th level']
# ['mauricio-world-info-test-exercise', 'ariel_world_info', 'world_info_ruben1984', 'world_info_jack_kk', 'David19652_world_info']
# ['world_info_camilla', 'HA2023', 'christian_world_info', 'shubham8_example_dataset', 'Alfredo2_world_info']
# ['AP_example_dataset', 'world_info_jack', 'mohsen_example_dataset', 'olav_world_info', 'Ravi_World_info2']
# ['Tatsiana1994test', 'world_info_gcbiotec', 'pratish_integrate_dataset', 'test_dataset4', 'my_example_dataset_wu_2']
# ['Jose_example_dataset', 'xxxxx_DP_TestDS', 'TestDataset', 'maude_world_info', 'Harsha2000-AvevaNet']
# ['jz_world_info', 'world_info_jack_003', 'PM_world_info', 'rawanaltaha_world_info', 'world_info_maciej1977-v3']
# ['Vaishnavi_example_dataset', 'world_info_jack', 'yaswanth_world_info', 'world_info_jb', 'fjpg_world_info_jack']
# ['world_info_jack_1', 'world_info_jacktestfdafsdf', 'Simon_world_info', 'ole_wammer_world_info', 'LGH1']
# ['world_info_H', '222nd level', 'Arya_World_Info', 'teodor_world_info', 'GCH_world_info']
# ['tsk_world_info', 'my_example_dataset', 'irma_test', 'irma_test', 'world_info_asade']
# ['Shaurya_2023-ds', 'world_info_jack', 'my_example_dataset1', 'Simon_world_info', 'world_info_rui']
# ['world_info_jack', 'world_info_camilla2', 'gcbiotec_world_info2002A', 'world_info_SumitB', 'jeeva_world_info']
# ['GCH_world_info', 'my_example_dataset', 'my_test_dataset', 'camilla1996_world_info', 'PM_world_info']
# ['Rafli_world_info', 'clement_world_info', 'world_info_jack_lundemo', 'neil_world_info', 'DP_TestDS']
# ['Srujana_world_info', 'hmnasri_world_info', 'world_info_jack', 'world_info_jack', 'world_info_maxim']
# ['Aranya_example_dataset', 'as_dataset1', 'dls_example_dataset', 'Shirin_world_info', 'Rafli_world_info']
# ['Sudil1997', 'jn_example_dataset', 'cristian_example_dataset', 'sid1974', 'hmnasri-CDF']
# ['caroline_f_world_info2', 'Aranya_world_info', 'my_example_dataset_saketh', 'Simon_world_info', 'my_ds']
# ['christian_world_info', 'world_info_andrew', 'heman_2nd_dateset', 'my_world_info', 'Aqilah1993-AvevaNet']
# ['GCH_world_info', 'mylittlepony_world_info', 'work_info_jack', 'world_info_moe4', 'second example']
# ['world_info_jack_002', 'kiyoshi_world_info', 'my_example_dataset', 'my_example_dataset_k', 'second example']
# ['world_info_jack_test1', 'Dzmitry1994_world_info', 'victor1_example_dataset', 'Tat2_world_info', 'Alf57_world_info']
# ['Aidar_world_info', 'world_info_jack', 'Saurabh_world_info', 'E_world_info', 'test_dataset7']
# ['world_info_jack_111', 'world_info_orjanm', 'ConocoPhillips_Sensor', 'dp1998', 'world_info_anto']
# ['Saurabh_world_info', 'hamdi_world_info', 'my_example_dataset_sebastian1999', 'Adriano2024_example_dataset', 'AElena_world_info']
# ['gustavo_world_info', 'Simon_world_info', 'world_info_jack', 'world_info_Hachem', 'jeeva_testing']
# ['cdf_training_fjpg2', 'world_info_jack_rack', 'ownworld_info_jack', 'palvo_world_info', 'Ravi_World_info4']
# ['yoan_world_info', 'Jorgen_world_info', 'my_example_dataset', 'Custom Create Dataset', 'lucas_2000_example_dataset']
# ['Paniz_example_dataset', 'world_info_dima', 'Aidar_world_info', 'world_info_test', 'world_info_jack329']
# ['world_info_jack', 'demo23', 'my_example_dataset', 'pallab_example_dataset', 'Valhall OID']
# ['Maciukas_world_info', 'Teste_Teste_Teste', 'world_info_jack', 'world_info_jack', 'my example']
# ['my_example_dataset_js2001', 'Istvan_world_info', 'DipeshY_world_info', 'tsk_world_info', 'lsun_example_dataset2']
# ['gabor_world_info', 'leann1993_world_info_jack', 'elize_world_info', 'zhanat_world_info', 'my_example_datasetcs']
# ['sid1974-world_info', 'world_info', 'mikita_world_info', 'test_dataset3', 'my_example_dataset']
# ['srujana_world_info', 'HansGünter_example_dataset', 'my_example_dataset_ww', 'world_info_jac', 'Pavan1978-IFSDB']
# ['MatiasRamsland_world_info', 'third example', 'Mark303-IFSDB', 'Sean1985_world_info', 'Vipul_example_dataset']
# ['2nd level_test', 'emma_example_dataset', 'JP 2nd level', 'world_info_jack', 'irma_test']
# ['world_info_orjan', 'ds_4', 'pallab_world_info', 'PM_2nd level', 'Jorgen_world_info']
# ['world_info_jack_name', '1st lavel', 'felipef_example_dataset', 'world_info_john_3', 'GCH_world_info']
# ['world_info_maksym1981_2', 'my_example_datasetEPC', 'Him3_dataset', 'my_example_dataset', None]
# ['world_info_mugless', 'paco_example_dataset', 'anj_world_info', 'my_example_dataset', 'my_name2_example_dataset']
# ['world_info_jack_mm1', 'my_example_dataset_nick', 'Mudassir_world_info', 'toye_world_info', 'clayton_harlin_world_info']
# ['TestDataset', 'world_info_jack123a', 'mauricio-world-info-test2-exercise', '1st level', 'Ruslan_world_info']
# ['world_info_jack_name', 'TestDataset', 'Training1-AvevaNet', 'PM_world_info', 'irma_test']
# ['world_info_jack', 'Simon_world_info', 'my_name___example_dataset', 'world_info_xiaozhang', 'world_info_jack_mariana']
# ['PM_world_info', 'world_info_jack_Shirin', '2nd level', 'hanson1', 'josip_example_dataset']
# ['breno_word_info', 'world_info_YuiNish', 'world_infojac', 'PM_my_veryown_dataset', 'Tat_dataset']
# ['world_info_jack_abhi', 'rs_my_example_dataset', 'world_info_jack_name', '2ndLevel', 'world_info_jack']
# ['christian_world_info', 'test_dataset6', 'Matthew1991_world_info', 'Matthew1991-AvevaNet', 'Simon_world_info']
# ['pawel_world_info', 'Mudassir_world_info', 'Vipul_world_info', 'JohnS1984_example_dataset', 'myhk_example_dataset']
# ['world_info', 'my_example_dataset', 'third example', 'neil_v_world_info', 'DP_TestDataSet1']
# ['world_info_academy', 'Khobar2023-IFSDB', 'irma_test', 'my example', 'Kush_world_info']
# ['rsk_ds1', 'my_example_dataset485', 'Ravi_World_info5', 'my_example_dataset', 'Ruslan_world_info']
# ['ali_world_info', 'world_info_jack', 'world_info_rsk', 'my_example_dataset1', 'Mikalay1991:world_info']
# ['my_example_dataset', 'Task_21_07_23', 'second example', 'Aranya_world_info', 'world_info_jack']
# ['Jorgen_world_info', 'world_info_jackP', 'lsun2_world_info', 'world_info_chandc2', 'ds_3']
# ['world_info_raluca', '2nd level', 'world_info_rsk1', 'Mudassir_world_info', None]
# ['world_info_jack_100', 'test', 'world_info_moe1', 'Marcos_world_info', 'dalvania_world_info_3']
# ['Adriano2024-world_info_jack', 'my example dataset', 'jz_example_dataset', 'kiyoshi_world_info', 'PM_world_info']
# ['world_info_jack', 'world_info_jack_mm11', '2nd level', 'world_info_jack_101', 'E_world_info']
# ['Yining1979-AvevaNet', 'world_info_mm', 'world_info_jack', '1st level Kruti', 'jon_world_info']
# ['third example', 'Mudassir_world_info', 'irma_test', 'GustavoTostes_world_info', 'my_example_dataset3']
# ['Maciej_example_dataset', 'world_info_jack', 'cp_wells', 'world_info_nlm', 'Nick0000-AvevaNet']
# ['clement_world_info', 'my_example_dataset', 'world_info_jack', 'my_example_datasetcasa', 'dasor_world_info']
# ['world_info_marissa2', 'world_info_nlm_2', 'renan_example_dataset', 'world_info_jack', 'Maria_world_info']
# ['my_name', None, 'world_info_jack_0', 'EH_world_info', 'Abi1234567_example_dataset']
# ['gabriel1986_dataset', 'world_info_moe5', 'jz_example_dataset_1', 'world_info_jason', 'my_example_dataset197']
# ['world_info_jack', 'world_info_jonathan', 'christian_world_info', 'my_example_dataset', 'test_dataset9']
# ['mw_world_info', 'third example', 'Mudassir_world_info', 'world_info_jack', '2nd level']
# ['Fred2_example_dataset', 'my_example_dataset_Manvendra', 'world_info_jack1', 'world_info_jack', 'kiyoshi_world_info']
# ['Morten_world_info', 'Test', 'world_info_jack_mm113', 'world_info_jack', 'my_example_dataset_gui']
# ['world_info_jack', 'Gushino_world_info', 'Trial_Itika_Dataset', 'abhishek1996_dataset', 'Istvan_dataset']
# ['1st level', 'subodh_dataset', 'Hasib1994-AvevaNet', '2nd level-gs', 'world_info_jack_99']
# ['world_info_jack', 'my_example_dataset', 'hest_example_dataset', 'Sumit1998-AvevaNet', 'my_example_dataset_2']
# ['dasor_world_info', 'gcbiotec_world_info99', 'Luis1977_world_info', 'world', 'Ali-97-AvevaNet']
# ['zhanat_example_dataset', 'joar_example_dataset', 'Mudassir_world_info', 'Raluca_world_info', 'tutorial_name']
# ['world_info_jack', 'world_info_wwu', 'TSPL_Data', 'ariel_world_info', 'world_info_jack22222']
# ['world_info_moe2', 'kiyoshi_world_info', None, 'world_info_jack_sid', 'EmiliesDS']
# ['lean20273world_info_jack', 'world_info_jack', 'irma_test', 'world_info_jack', 'my_example_dataset_2']
# ['world_info_mark306', 'Aman_example_dataset', 'world_info_maciej1977', 'PM_world_info', 'pallabg_world_info']
# ['faris_world_info', 'Andrian_world_info', 'world_info_ole', 'heman_example_dataset', 'mojtaba_world_info']
# ['TestDataset', 'Muhammed_Muddaththir_world_info_t', 'my_example_dataset_003', 'ariel_world_info', 'my_example_dataset3a']
# ['world_info_kk', 'Saurabh_world_info', 'world_info_jayanth2', 'mohsen_world_info', 'my_example_dataset_aguiar']
# ['Teste_Teste_Teste', 'ourworld_info_jack', 'Simon_world_info', 'E_world_info', 'world_info_danger82']
# ['E_world_info', 'Him_my_example_dataset', 'world_info_jack_jj', 'world_info_elize', 'my example']
# ['my_name_example_dataset', 'world_info_jack_999', 'christian_world_info', 'Aidar_world_info', 'Gaurav Rajurkar_world_info']
# ['amin_dataset', 'xiaozhang_world_info', 'world_info_adonis', 'Renaud66_example_dataset', 'Islas1994_example_dataset']
# ['camilla1996_world_info', 'sharizan1981_dataset', 'palvo_world_info', 'my_example_datasett', 'EH_example_dataset']
# ['PM_world_info', 'gabor_world_info', 'third example', 'my_example_dataset', 'world_info_jack']
# ['world_Info_Utt', 'irma_test', 'my example', 'NKTestF', 'NKTest1234']
# ['third example', '1st', 'FirstnameBirthyear-AvevaNet', 'JH 2nd Level', 'colin1985_world_info']
# ['1337_hello_world', 'JH 3rd Dataset', 'Aranya7_world_info', 'E_world_info', 'subham_dataset']
# ['E_world_info', 'test123', 'third example', '22nd level', 'Aranya8_world_info']
# ['005Khobar_world', 'test_example_dataset', 'ali_ht', 'world_info_icaro1993', '2nd level K']
# ['subham_sarangi_world_info', 'olav_world_info', 'my_dataset', 'world_info_jack_ilya', 'Ajit1992-AvevaNet']
# ['Simon_world_info', 'my_example_dataset', 'world_info_jack', 'palvo_world_info', 'michael2024_example_dataset']
# ['Abdulmonim_World_info', 'Maciej_world_info', 'Saurabh_world_info', 'world_info_afii', 'world_info_abhinav']
# ['Emilie_world_info', 'world_info_msksym', 'jz-dataset', 'Simon_world_info', 'my_example_dataset1123121']
# ['Hasan Hindi Hands On DataSet Practice', 'world_info_jack_sachin', 'my_example_dataset23456', 'dayvid_work_info', 'PM_world_info']
# ['my_example_dataset_0', 'jcm_world_info_jack', 'world_info_Paul', 'heydar_worl_info', '22nd level']
# ['Alfredo2_world_info', 'world_info_jack', 'kiyoshi_world_info', 'Raluca_world_info', 'world_info_jube']
# ['Philips Dataset', 'mcduque_world_info', 'roop_dataset', 'myfirstlevel_H', 'Jorgen_world_info']
# ['christian_world_info', 'First Level', 'irma_dev_dataset', 'world_info_jack', '1st level']
# ['mcduque_world_info', 'Aranya_world_info', 'world_info_jack', 'Valhall system 23 P&IDs', 'christian_world_info']
# ['Mohamed1996', 'Aranya9_world_info', 'Ben1980-AvevaNet', 'my_example_dataset_saurabh', 'Aranya1_world_info']
# ['world_info_Root_Assert_Error_Test_001', 'world_info_jack', 'orjan_world_info', 'world_info_jack', 'testing_199']
# ['Ruslan_world_info', 'victor_example_dataset', 'heydar_worl_info', 'Kush_myexample_dataset', 'my_example_dataset1']
# ['Itika_Dataset', 'Ravi_World_info', 'Rafli_world_info', 'world_info_jack', 'GCH_world_info']
# ['gcbiotec_world_info1902', 'mauricio_example_dataset', '000Khobar_world', 'world_info_jack', 'Morten1988_dataset']
# ['montadharR_world_info_jack', 'ds_novajj', 'maude_world_info', 'bb_example_dataset', 'my_example_dataset']
# ['cp_wells', 'my_tagSDK._example_dataset', 'Alf58_world_info', 'rena_1990_example_dataset', 'kliang_example_dataset']
# ['dalvania_world_info_2', 'Muddassirmm11', 'Aditya1999-IFSDB', 'andreas1997_example_dataset', 'Mikalay1991:world_info']
# ['world_info_jack_12', 'Rafli_world_info', 'crístian_example_dataset', 'orjan_example_dataset', 'world_info_greynoso71']
# ['world_info_jack', 'lucas_world_info', 'Lucas1995_world_info', 'kp0428_dataset', 'world_info_jack']
# ['my_example_dataset_tim', 'world_info_Mugless', 'world_info_satz', 'palvo_world_info', 'my example']
# ['DSING', '2nd level', 'my_example_dataset', 'yahya_world_info2', 'MED2024_example_dataset']
# ['world_info_aida_1990', 'MyTestNK', 'my_name____example_dataset', 'my_example_dataset', 'mfc_world_info']
# ['1st level', 'Kushagra_world_info', 'world_info_jack', 'christian_world_info', '004Khobar_world']
# ['MuglessDurry_world_info', 'world_info_jack', 'felipef_world_info', 'Jorgen_world_info', 'bojja_srikar_world_info']
# ['my_example_dataset', 'meher_world_info', 'tim_world_info', 'HA2023', 'my_example_dataset_not_duplicate']
# ['ruben_world_info', 'my_example_dataset', 'ariel_world_info', 'Joa_world_info', 'my_example_dataset-anto']
# ['ariel_world_info', 'world_info_jack', 'GPaulo2000-AvevaNet', 'Ravi_dataset', 'world_info_iii']
# ['world_info_mark303', 'LC_2nd level', '11st level', 'NKTestF', 'bojja_world_info']
# ['world_info_jack_k', 'world_info_jack_hp', 'felipef_world_info', 'my_example_dataset', 'world_info_islas1994']
# ['Aranya6_world_info', 'world_info_jack_anubhav', 'mauricio1984_world_info', 'Achilles_World Info', 'world_info_jack']
# ['my_example_dataset_fh', 'gabor_world_info', 'Ariel2000_HandsOn', 'second example', '1st level_test']
# ['first level', 'Syl1982-AvevaNet', 'dawei_world_info_jack', 'patrick1998_world_info', 'my_example_dataset333333']
# ['NKTest123', 'jay_example_dataset', 'irma_test', 'world_info_jack', 'my example']
# ['Obeida_world_info', '1st level', 'my_example_dataset_240311', 'vetle_world_test', 'sohab_dataset1']
# ['jz_world_info', 'heydar_worl_info', 'world_info_jack12', 'my example', '2nd level']
# ['world_info_test_22', 'world_info_jack157', 'E_world_info', 'E_world_info', 'Alfredo_world_info']
# ['2nd level_m', 'my_example_dataset_agnes', 'world_info_jack', 'Adriano2024_101_world_info_level_1', 'world_info_jack_abhi1']
# ['renanlt_example_dataset', 'Aidar_world_info', 'world_info_wwu', 'world_info_jack', 'cdf_training_fjpg']
# ['world_info_asade1', 'Ajit1992-AvevaNet', 'Valeriya_world_info', 'DP_TestDS', 'world_info_jack']
# ['my_example_dataset_Obz', '001Khobar_world', 'Garcia_example_dataset', '002Khobar_world', 'lucas_hc_example_dataset']
# ['world_info_Gus', 'ermias_world_info', 'bentekassie_dataset', 'world_info_jack', 'christian_world_info']
# ['second example', 'NKTestF', 'world_info_antonia', 'world_info_jackq', 'world_info_jack_name']
# ['Ana_world_info', 'Rostyslav1984-AvevaNet', 'Maksym1981-IFSDB', 'world_info_pal', 'my_example_dataset_sid']
# ['yeshwanth_4545-ds', 'world_info_jack', 'Simon_world_info', 'Dzmitry1994_world_info', 'my_example_dataset']
# ['FirstnameBirthyear-AvevaNet', 'world_info_Pal', 'world_info_jack', 'Monica72-AvevaNet', 'Fred_example_dataset']
# ['2nd level', 'world_info_jack', 'Luis1977-AvevaNet', 'world_info_tim2', 'my_example_dataset']
# ['1st level', 'marissa_data_set', None, 'JorgenAa_world_info', '13_world_info_jack']
# ['mylittlepony_world_info', 'Hiral1982-IFSDB', 'Maksym1981-AvevaNet', 'my_example_dataset', 'TestDataset']
# ['world_info_andrew', 'Achilles_World Info', 'test_dataset5', 'world_info_jack1_new', '1st level']
# ['world_info_jack_sid2001', 'Test_dataset-vidhi', 'Monica72-IFSDB', 'NKTestF', 'meher_world_info']
# ['world_info_neck', 'caroline_f_example_dataset', 'world_info_jack_hv', 'TestDataset', 'world_info_jack']
# ['Simon_world_info', 'Mohamed1996', 'Mudassir_world_info', 'my example', 'jz_example_dataset_2']
# ['camilla1996_world_info', 'world_info_jackz2', 'magnus_world_data', 'Dzmitry1994_world_info', '1st level']
# ['world_info_jack', 'Vani_sample', 'world_info_andreea', 'NKTestDS', 'fahmi_world_info']
# ['my example', 'Michail1981_example_dataset', 'udantha_dataset', 'christian_world_info', 'third example']
# ['Jorgen_world_info', 'kiyoshi_world_info', 'world_info_Root_Assert_Error_Test_003', 'my_example_dataset22', 'mehmet1997_dataset']
# ['SofieFH', 'heydar_worl_info', 'Jan1975-AvevaNet', 'Testssss', 'world_info_jack_name']
# ['world_info_gustavo', 'Rishay1997-AvevaNet', 'Raluca_world_info', 'world_info_wdj', 'Valeriya_world_info']
# [None, 'Vijaya-1998-ds', 'my_example_dataset_Marcos1995', 'second example', 'world_info_jack']
# ['world_info_andrew', 'third example', '2st lvl', 'mark303_example_dataset', 'world_info_jack']
# ['my example', 'world_info_jack', 'second example', 'PM_1st level', 'Maciej1977-DataSetAPITest']
# ['xiao_world_info', 'vetle_world_info', 'Rafli_world_info', 'third example', 'Arijit_example_dataset']
# ['gaurav-1991-AvevaNet', 'irma_test', 'madina_dataset', 'GCH_world_info', 'my_example_dataset']
# ['Christian_world_info', 'world_info_subham', 'test_ds', None, 'vetle_world_info']
# ['krny_world_info_jack', 'Shubham26_example_dataset', 'world_info_jack_Manav', 'LenninPalacios1998-AvevaNet', 'dayvid_work_info']
# ['my_example_datasetD', 'Muddassirmm', 'world_info_jack', 'TestDataset', 'hanson']
# ['world_info_andrew', 'yaswanth_world_info', 'world_info_Timi', 'my_example_dataset', 'kailash_world_info']
# ['my_example_dataset_w', 'lucas_mateus_world_info', 'world_info_mfc2', 'vetle_world_info', '2nd level']
# ['world_info_mark304', 'srujana_world_info', 'Mudassir_world_info', 'Mikalay1991:world_info', 'Ruslan_world_info']
# ['Quoc_world_info', 'irma_test', 'third example', 'mduque_world_info', 'Dzmitry1994_world_info']
# ['Second Level', 'C-Assets', '1st level KrutiLtts', 'Ravi_World_info4', 'Mark303-IFSDB']
# ['Akeel_example_dataset', 'alex_world_info', 'VFMP_TI0IDOdYbV', 'world_info_jack', 'christian_world_info']
# ['world_info_jack_test1', 'kzhao_example_dataset', 'mauricio-test-world-info', 'world_info_moe', 'dls_example_dataset']
# ['world_info_chand', 'my_example_dataset_srujana', 'Yahya_example_dataset', 'TestDataset', 'sohab_dataset']
# ['datasetSree', 'my_example_dataset_x', 'Rajat1985-AvevaNet', 'hmnasri-CDF2', 'Emilie_world_info']
# ['my_example_dataset', 'world_info_pat', 'Abi123456_example_dataset', 'my_example_dataset', 'Mudassir65 DataSet Testing']
# ['subodh_world_info', 'world_info_jack_mm111', 'Hiral1982-Assets', 'gk74_example_dataset', 'my_example_dataset']
# ['world_info_kp', 'joshua_stanley_world_info', 'nk_1997_example_dataset', 'Aishwarya1996', 'faris9999']
# ['Maciukas_world_info', 'world_info_jack', 'Paniz_world_info', 'Practice-JS2001', 'world_info_maciej1977-v2']
# ['my_example_dataset', 'krishna2001-AvevaNet', 'my_example_dataset1', 'Abacus24_world_info_dataset', 'jz_world_info']
# ['Gus_world_info', 'world_info_jack_MMTEST', 'world_info_jack', 'world_info_N1980', 'world_info_alex_n']
# ['1st level', 'Disha_world_info_jack', 'world_info_jack', 'world_info_jack1', 'chandradeep1947-AvevaNet']

# %% [markdown]
# ## Searching in CDF
#
# - Search the CDF resource types
# - Filter the search results
#
# **Code Pattern**
#
# `client.<cdf_resource_type>.search()`

# %% [markdown]
# ### Fuzzy Search on one field

# %%
c.assets.search(name="Norway",limit=5)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x1e1f38abfd0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36d2c50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3847350>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38ab990>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f38d72d0>])

# %%
c.time_series.search(name="North",limit=5)
# Out:
# TimeSeriesList([<cognite.client.data_classes.time_series.TimeSeries at 0x1e1f3aa3ed0>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x1e1f3845150>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x1e1f381b050>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x1e1f1d710d0>,
#                 <cognite.client.data_classes.time_series.TimeSeries at 0x1e1f38ea190>])

# %%
c.files.search(name="sheet")
# Out:
# FileMetadataList([<cognite.client.data_classes.files.FileMetadata at 0x1e1f38eb010>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f3ab12d0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38eb450>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38e8f90>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38e8750>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38e9cd0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38e9350>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38d71d0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38d6fd0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38ebc90>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38d7e90>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38d6e10>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38d7950>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38d7d10>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f6550>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f6510>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f64d0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f6350>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f6490>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f6450>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f6410>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f63d0>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f6390>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f6310>,
#                   <cognite.client.data_classes.files.FileMetadata at 0x1e1f38f65d0>])

# %% [markdown]
# Similarly for sequences and events

# %% [markdown]
# `c.sequences.search(name="some name")`
#
# `c.events.search(description="some description")`

# %% [markdown]
# ### Multi-field fuzzy search

# %%
c.assets.search(query="Nor",limit=5)
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x1e1f36d3b90>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3a9f490>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f1773f10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa05d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa0ed0>])

# %% [markdown]
# ### Exact search on one field (e.g. name, description etc)

# %%
c.assets.search(filter={"name": "Canada"})
# Out:
# AssetList([<cognite.client.data_classes.assets.Asset at 0x1e1f3827b10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa35d0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa0b50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa1610>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa1250>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa1910>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3846410>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f36f4910>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa3e50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3aa3610>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab1e90>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab0dd0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2e10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2c50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2d90>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2d50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2d10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2cd0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2c90>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2c10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2ed0>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2e90>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2f10>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2f50>,
#            <cognite.client.data_classes.assets.Asset at 0x1e1f3ab2f90>])

# %% [markdown]
# get all timeseries for the above asset

# %%
c.time_series.search(filter={"asset_ids":[8516698919785878]})

# %%
c.events.list()[0].type

# %%
# First get an example type to filter on
example_type = c.events.list()[0].type
# Filter the events of that type
c.events.search(filter={"type":example_type})

# %% [markdown]
# ### Multiple filters in search function

# %%
c.assets.list(limit=5,data_set_external_ids=['world_info_academy'])

# %%
c.data_sets.list()

# %%
c.assets.list(root=True)

# %%
c.assets.search(name="San",filter={"parent_ids": [349354003007241]})

# %% [markdown]
# ### Filter asset search using Label Filter

# %%
from cognite.client.data_classes import AssetFilter

# %%
c.assets.search(name="Norway",filter=AssetFilter(labels=LabelFilter(contains_all=["cold-countries"])),limit=5)

# %%
c.assets.search(name="Can",filter=AssetFilter(labels=LabelFilter(contains_all=["cold-countries"])),limit=5)

# %% [markdown]
# ## Retrieve the CDF resource types and data
#
# ### Code Pattern
# `client.<cdf_resource_type>.retrieve()`
#
# `client.<cdf_resource_type>.retrieve_multiple()`

# %% [markdown]
# ### Retrieve the CDF resource types

# %% [markdown]
# single item - using id

# %%
c.data_sets.list()

# %%
# id of dataset
c.data_sets.retrieve(id=2238694842784134)

# %%
c.time_series.retrieve(id=2238694842784134)

# %%
import datetime
# id of timeseries
c.time_series.data.retrieve(id=658605450035112, start=datetime.datetime(2018,1,1), end=datetime.datetime(2018,2,1))

# %% [markdown]
# single item - using external_id

# %%
c.data_sets.retrieve(external_id = "world_info_academy")

# %% [markdown]
# multiple items - using ids

# %%
c.data_sets.list()

# %%
c.data_sets.retrieve_multiple(ids=[39210236434027, 145208858652069])

# %% [markdown]
# multiple items - using external_ids

# %%
c.data_sets.retrieve_multiple(external_ids=["test_dataset1", "test_dataset2","my_important_dataset"], ignore_unknown_ids=True)

# %%
from datetime import datetime
# Don't put a long datetime range, as it'll fetch all the raw datapoints, which can be huge
c.time_series.data.retrieve(external_id=['Nauru_population','Spain_population'],start=datetime(2000,1,1),end=datetime(2024,1,2))

# %% [markdown]
# ### Retrieve all items related to an asset

# %%
# get the asset object for "Europa"
asset_obj = c.assets.retrieve(id = 349354003007241)

# %%
asset_obj

# %% [markdown]
# Asset Subtree

# %%
c.assets.retrieve_subtree(id = 349354003007241)

# %% [markdown]
# Children

# %%
asset_obj.children()

# %% [markdown]
# Parent

# %%
asset_obj.parent()

# %% [markdown]
# Events

# %%
# get the asset object for "Italy"
asset_obj = c.assets.retrieve(id = 2689912833887590)

# %%
asset_obj.events(limit=-1)

# %% [markdown]
# Timeseries

# %%
# get the asset object for "Italy"
asset_obj = c.assets.retrieve(id = 2689912833887590)

# %%
asset_obj.time_series()

# %% [markdown]
# ### Retrieve data

# %% [markdown]
# #### Retrieve Raw Data

# %%
# Don't put a long datetime range, as it'll fetch all the raw datapoints, which can be huge for Raw datapoints
c.time_series.data.retrieve(id=239507005016003, end='now')

# %% [markdown]
# #### Retrieve Aggregated data

# %%
c.time_series.data.retrieve_dataframe(id=239507005016003,
                    end='1000w-ago',
                    aggregates=["average","sum"],
                    granularity="1h")

# %% [markdown]
# Retrieve latest datapoint before a particular time (last or any past time point)

# %%
c.time_series.data.retrieve_latest(id=239507005016003, before="5w-ago")[0]

# %% [markdown]
# ### Plot the data points

# %%
c.time_series.data.retrieve(id=239507005016003, end='1000w-ago').to_pandas().plot()

# %% [markdown]
# ### Download files

# %% [markdown]
# Download files to disk

# %%
files_list = c.files.search(filter={"uploaded":True},limit=5)
files_list

# %%
! mkdir files

# %%
c.files.download(directory="files", id=[202614441188439, 4009508514690241])

# %% [markdown]
# Download a single file to a specific path

# %%
c.files.download_to_path("files/test.svg", id=202614441188439)
